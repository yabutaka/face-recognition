# %%
import tensorflow
import os
from matplotlib import pyplot

# %%
# # example of loading the keras facenet model
# from keras.models import load_model
# os.chdir('/Users/yabutamidori/Desktop/Work/AnchorZ/Projects/ARM/models/20180408-102900')
# # load the model
# model = load_model('20180408-102900.pb')
# # summarize input and output shape
# print(model.inputs)
# print(model.outputs)

# %%
print(tensorflow.__version__)
# Out:
# 1.10.0

# %%
# confirm mtcnn was installed correctly
import mtcnn
# print version
print(mtcnn.__version__)
# Out:
# 0.0.9

# %%
owd = os.getcwd()
os.chdir('/Users/yabutamidori/Desktop/Work/AnchorZ/Projects/ARM')

# %%
owd = os.getcwd()
owd
# Out:
# '/Users/yabutamidori/Desktop/Work/AnchorZ/Projects/ARM'

# %%
# function for face detection with mtcnn
from PIL import Image
from numpy import asarray
from mtcnn.mtcnn import MTCNN

filename = "picutre.jpg"
# load image from file
image = Image.open(filename)
# convert to RGB, if needed
image = image.convert('RGB')
# convert to array
pixels = asarray(image)

# %%
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
results = detector.detect_faces(pixels)

# %%
results
# Out:
# [{'box': [211, 288, 610, 821],
#   'confidence': 0.9986728429794312,
#   'keypoints': {'left_eye': (366, 609),
#    'right_eye': (654, 620),
#    'nose': (491, 789),
#    'mouth_left': (367, 897),
#    'mouth_right': (620, 911)}}]

# %%
# extract the bounding box from the first face
x1, y1, width, height = results[0]['box']
# bug fix
x1, y1 = abs(x1), abs(y1)
x2, y2 = x1 + width, y1 + height

# %%
# extract the face
face = pixels[y1:y2, x1:x2]

# %%
# resize pixels to the model size
image = Image.fromarray(face)
image = image.resize((160, 160))
face_array = asarray(image)

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=160x160 at 0x1C35E0AD68>

# %%
# extract a single face from a given photograph
def extract_face(filename, required_size=(160, 160)):
	# load image from file
	image = Image.open(filename)
	# convert to RGB, if needed
	image = image.convert('RGB')
	# convert to array
	pixels = asarray(image)
	# create the detector, using default weights
	detector = MTCNN()
	# detect faces in the image
	results = detector.detect_faces(pixels)
	# extract the bounding box from the first face
	x1, y1, width, height = results[0]['box']
	# bug fix
	x1, y1 = abs(x1), abs(y1)
	x2, y2 = x1 + width, y1 + height
	# extract the face
	face = pixels[y1:y2, x1:x2]
	# resize pixels to the model size
	image = Image.fromarray(face)
	image = image.resize(required_size)
	face_array = asarray(image)
	return face_array

# %%
# demonstrate face detection on 5 Celebrity Faces Dataset
from os import listdir
# specify folder to plot
folder = 'train_images/m.01_0vk/'
i = 1
# enumerate files
for filename in listdir(folder):
	# path
	path = folder + filename
	# get face
	face = extract_face(path)
	print(i, face.shape)
	# plot
	pyplot.subplot(2, 7, i)
	pyplot.axis('off')
	pyplot.imshow(face)
	i += 1
pyplot.show()
# Out:
# 1 (160, 160, 3)
# 2 (160, 160, 3)
# 3 (160, 160, 3)
# 4 (160, 160, 3)
# 5 (160, 160, 3)
# 6 (160, 160, 3)
# 7 (160, 160, 3)
# 8 (160, 160, 3)

# %%
folder = "train_images"
# len(listdir(folder))
size_files = []
for subdir in listdir(folder):
    size_files.append(len(listdir(folder + "/" + subdir)))

# %%
sum(size_files)
# Out:
# 10001

# %%
len(size_files)
# Out:
# 230

# %%
10001 * 0.2 / 230
# Out:
# 8.696521739130436

# %%
460 / 10001
# Out:
# 0.045995400459954004

# %%
import pandas as pd
pd.DataFrame(size_files).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1c41c32438>]],
#       dtype=object)

# %%
from os.path import isdir

def load_faces(directory):
	faces = list()
	# enumerate files
	for filename in listdir(directory):
		# path
		path = directory + filename
		# get face
		face = extract_face(path)
		# store
		faces.append(face)
	return faces

def load_dataset(directory):
	trainX, trainy, testX, testy = list(), list(), list(), list()
	# enumerate folders, on per class
	for subdir in listdir(directory):
		# path
		path = directory + '/' + subdir + '/'
		# skip any files that might be in the dir
		if not isdir(path):
			continue
		# load all faces in the subdirectory
		faces = load_faces(path)
		# create labels
		labels = [subdir for _ in range(len(faces))]
		# summarize progress
		print('>loaded %d examples for class: %s' % (len(faces), subdir))
		# store
		trainX.extend(faces[2:])
		trainy.extend(labels[2:])
		testX.extend(faces[:2])
		testy.extend(labels[:2])
	return asarray(trainX), asarray(trainy), asarray(testX), asarray(testy)

# load train dataset
trainX, trainy, testX, testy = load_dataset('train_images')
print(trainX.shape, trainy.shape)
print(trainX.shape, trainy.shape)
# Out:
# >loaded 27 examples for class: m.01_8xh
# >loaded 60 examples for class: m.01_df6
# >loaded 15 examples for class: m.01_qht
# >loaded 34 examples for class: m.01_z4l
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-88-3d984b909710> in <module>
#      36
#      37 # load train dataset
# ---> 38 trainX, trainy, testX, testy = load_dataset('train_images')
#      39 print(trainX.shape, trainy.shape)
#      40 print(trainX.shape, trainy.shape)
#
# <ipython-input-88-3d984b909710> in load_dataset(directory)
#      23                         continue
#      24                 # load all faces in the subdirectory
# ---> 25                 faces = load_faces(path)
#      26                 # create labels
#      27                 labels = [subdir for _ in range(len(faces))]
#
# <ipython-input-88-3d984b909710> in load_faces(directory)
# ...

# %%
os.getcwd()
# Out:
# '/Users/yabutamidori/Desktop/Work/AnchorZ/Projects/ARM'
